# %% [markdown]
# # JSON examples and exercise
# ****
# + get familiar with packages for dealing with JSON
# + study examples with JSON strings and files
# + work on exercise to be completed and submitted
# ****
# + reference: http://pandas.pydata.org/pandas-docs/stable/io.html#io-json-reader
# + data source: http://jsonstudio.com/resources/
# ****

# %%
import pandas as pd

# %% [markdown]
# ## imports for Python, Pandas

# %%
import json

# %% [markdown]
# ## JSON example, with string
#
# + demonstrates creation of normalized dataframes (tables) from nested json string
# + source: http://pandas.pydata.org/pandas-docs/stable/io.html#normalization

# %%
# define json string
data = [{'state': 'Florida', 
         'shortname': 'FL',
         'info': {'governor': 'Rick Scott'},
         'counties': [{'name': 'Dade', 'population': 12345},
                      {'name': 'Broward', 'population': 40000},
                      {'name': 'Palm Beach', 'population': 60000}]},
        {'state': 'Ohio',
         'shortname': 'OH',
         'info': {'governor': 'John Kasich'},
         'counties': [{'name': 'Summit', 'population': 1234},
                      {'name': 'Cuyahoga', 'population': 1337}]}]

# %%
# use normalization to create tables from nested element
pd.json_normalize(data, 'counties')
# Out:
#          name  population
# 0        Dade       12345
# 1     Broward       40000
# 2  Palm Beach       60000
# 3      Summit        1234
# 4    Cuyahoga        1337

# %%
# further populate tables created from nested element
pd.json_normalize(data, 'counties', ['state', 'shortname', ['info', 'governor']])
# Out:
#          name  population    state shortname info.governor
# 0        Dade       12345  Florida        FL    Rick Scott
# 1     Broward       40000  Florida        FL    Rick Scott
# 2  Palm Beach       60000  Florida        FL    Rick Scott
# 3      Summit        1234     Ohio        OH   John Kasich
# 4    Cuyahoga        1337     Ohio        OH   John Kasich

# %% [markdown]
# ****
# ## JSON example, with file
#
# + demonstrates reading in a json file as a string and as a table
# + uses small sample file containing data about projects funded by the World Bank
# + data source: http://jsonstudio.com/resources/

# %%
# load json as string
json_arr = json.load((open('data/world_bank_projects_less.json')))
print(type(json_arr))
json_arr[0]
# Out:
# <class 'list'>
# {'_id': {'$oid': '52b213b38594d8a2be17c780'},
#  'approvalfy': 1999,
#  'board_approval_month': 'November',
#  'boardapprovaldate': '2013-11-12T00:00:00Z',
#  'borrower': 'FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA',
#  'closingdate': '2018-07-07T00:00:00Z',
#  'country_namecode': 'Federal Democratic Republic of Ethiopia!$!ET',
#  'countrycode': 'ET',
#  'countryname': 'Federal Democratic Republic of Ethiopia',
#  'countryshortname': 'Ethiopia',
#  'docty': 'Project Information Document,Indigenous Peoples Plan,Project Information Document',
#  'envassesmentcategorycode': 'C',
#  'grantamt': 0,
#  'ibrdcommamt': 0,
#  'id': 'P129828',
#  'idacommamt': 130000000,
#  'impagency': 'MINISTRY OF EDUCATION',
#  'lendinginstr': 'Investment Project Financing',
#  'lendinginstrtype': 'IN',
#  'lendprojectcost': 550000000,
#  'majorsector_percent': [{'Name': 'Education', 'Percent': 46},
#   {'Name': 'Education', 'Percent': 26},
# ...

# %%
# load as Pandas dataframe
sample_json_df = pd.read_json('data/world_bank_projects_less.json')
sample_json_df
# Out:
#                                     _id  approvalfy board_approval_month  \
# 0  {'$oid': '52b213b38594d8a2be17c780'}        1999             November
# 1  {'$oid': '52b213b38594d8a2be17c781'}        2015             November
#
#       boardapprovaldate                                 borrower  \
# 0  2013-11-12T00:00:00Z  FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA
# 1  2013-11-04T00:00:00Z                    GOVERNMENT OF TUNISIA
#
#             closingdate                              country_namecode  \
# 0  2018-07-07T00:00:00Z  Federal Democratic Republic of Ethiopia!$!ET
# 1                   NaN                      Republic of Tunisia!$!TN
#
#   countrycode                              countryname countryshortname  ...  \
# 0          ET  Federal Democratic Republic of Ethiopia         Ethiopia  ...
# 1          TN                      Republic of Tunisia          Tunisia  ...
#
#     sectorcode source  status  supplementprojectflg  \
# ...

# %% [markdown]
# ****
# ## JSON exercise
#
# Using data in file 'data/world_bank_projects.json' and the techniques demonstrated above,
# 1. Find the 10 countries with most projects
# 2. Find the top 10 major project themes (using column 'mjtheme_namecode')
# 3. In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.

# %% [markdown]
# ### 1. Find the 10 countries with most projects

# %%
# load json file as Pandas dataframe
df = pd.read_json('data/world_bank_projects.json')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   sector                    500 non-null    object
#  1   supplementprojectflg      498 non-null    object
#  2   projectfinancialtype      500 non-null    object
#  3   prodline                  500 non-null    object
#  4   mjtheme                   491 non-null    object
#  5   idacommamt                500 non-null    int64
#  6   impagency                 472 non-null    object
#  7   project_name              500 non-null    object
#  8   mjthemecode               500 non-null    object
#  9   closingdate               370 non-null    object
#  10  totalcommamt              500 non-null    int64
#  11  id                        500 non-null    object
#  12  mjsector_namecode         500 non-null    object
# ...

# %%
# filter out regions
regions = df.regionname.unique()
countries_df = df[~df.countryname.isin(regions)]

# %%
# get the top 10
print(countries_df['countryname'].value_counts()[:10])
# Out:
# Republic of Indonesia              19
# People's Republic of China         19
# Socialist Republic of Vietnam      17
# Republic of India                  16
# Republic of Yemen                  13
# People's Republic of Bangladesh    12
# Kingdom of Morocco                 12
# Nepal                              12
# Republic of Mozambique             11
# Federative Republic of Brazil       9
# Name: countryname, dtype: int64

# %% [markdown]
# __Note:__ there are lots of ties.<br>
# ##### Alternative to account for the ties:

# %%
counts = countries_df['countryname'].value_counts()
project_counts_df = counts.to_frame()
project_counts_df.columns = ['nb_projects']
project_counts_df.reset_index(inplace=True)
project_counts_df = project_counts_df.rename(columns = {'index':'countryname'})
project_counts_df.head()
# Out:
#                      countryname  nb_projects
# 0          Republic of Indonesia           19
# 1     People's Republic of China           19
# 2  Socialist Republic of Vietnam           17
# 3              Republic of India           16
# 4              Republic of Yemen           13

# %%
nb_projects_arr = project_counts_df.nb_projects.unique()[:10]
nb_projects_arr
# Out:
# array([19, 17, 16, 13, 12, 11,  9,  8,  7,  6])

# %%
tops = []
for i in range(10):
    position = {}
    position['rank'] = i + 1
    position['nb_projects'] = nb_projects_arr[i]
    position['countries'] = project_counts_df[project_counts_df.nb_projects == nb_projects_arr[i]].countryname.values
    position['nb_countries'] = len(position['countries'])
    tops.append(position)

print(tops)
# Out:
# [{'rank': 1, 'nb_projects': 19, 'countries': array(['Republic of Indonesia', "People's Republic of China"],
#       dtype=object), 'nb_countries': 2}, {'rank': 2, 'nb_projects': 17, 'countries': array(['Socialist Republic of Vietnam'], dtype=object), 'nb_countries': 1}, {'rank': 3, 'nb_projects': 16, 'countries': array(['Republic of India'], dtype=object), 'nb_countries': 1}, {'rank': 4, 'nb_projects': 13, 'countries': array(['Republic of Yemen'], dtype=object), 'nb_countries': 1}, {'rank': 5, 'nb_projects': 12, 'countries': array(["People's Republic of Bangladesh", 'Kingdom of Morocco', 'Nepal'],
#       dtype=object), 'nb_countries': 3}, {'rank': 6, 'nb_projects': 11, 'countries': array(['Republic of Mozambique'], dtype=object), 'nb_countries': 1}, {'rank': 7, 'nb_projects': 9, 'countries': array(['Federative Republic of Brazil', 'Islamic Republic of Pakistan',
# ...

# %%
tops_df = pd.DataFrame(tops)
tops_df
# Out:
#    rank  nb_projects                                          countries  \
# 0     1           19  [Republic of Indonesia, People's Republic of C...
# 1     2           17                    [Socialist Republic of Vietnam]
# 2     3           16                                [Republic of India]
# 3     4           13                                [Republic of Yemen]
# 4     5           12  [People's Republic of Bangladesh, Kingdom of M...
# 5     6           11                           [Republic of Mozambique]
# 6     7            9  [Federative Republic of Brazil, Islamic Republ...
# 7     8            8  [United Republic of Tanzania, Republic of Taji...
# 8     9            7  [Kyrgyz Republic, Hashemite Kingdom of Jordan,...
# 9    10            6  [Republic of Kenya, Republic of Peru, West Ban...
#
#    nb_countries
# 0             2
# 1             1
# 2             1
# 3             1
# 4             3
# 5             1
# 6             3
# 7             3
# 8             4
# ...

# %% [markdown]
# ### 2. Find the top 10 major project themes (using column 'mjtheme_namecode')

# %%
df.mjtheme_namecode[0]
# Out:
# [{'code': '8', 'name': 'Human development'}, {'code': '11', 'name': ''}]

# %%
# load json file as string
json_arr = json.load((open('data/world_bank_projects.json')))
json_arr[0]
# Out:
# {'sector': [{'Name': 'Primary education'},
#   {'Name': 'Secondary education'},
#   {'Name': 'Public administration- Other social services'},
#   {'Name': 'Tertiary education'}],
#  'supplementprojectflg': 'N',
#  'projectfinancialtype': 'IDA',
#  'prodline': 'PE',
#  'mjtheme': ['Human development'],
#  'idacommamt': 130000000,
#  'impagency': 'MINISTRY OF EDUCATION',
#  'project_name': 'Ethiopia General Education Quality Improvement Project II',
#  'mjthemecode': '8,11',
#  'closingdate': '2018-07-07T00:00:00Z',
#  'totalcommamt': 130000000,
#  'id': 'P129828',
#  'mjsector_namecode': [{'code': 'EX', 'name': 'Education'},
#   {'code': 'EX', 'name': 'Education'},
#   {'code': 'BX', 'name': 'Public Administration, Law, and Justice'},
#   {'code': 'EX', 'name': 'Education'}],
#  'docty': 'Project Information Document,Indigenous Peoples Plan,Project Information Document',
#  'sector1': {'Percent': 46, 'Name': 'Primary education'},
#  'lendinginstr': 'Investment Project Financing',
# ...

# %%
# use normalization to create tables from nested element
df_norm = pd.json_normalize(json_arr, 'mjtheme_namecode', ['countryname'])
df_norm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1499 entries, 0 to 1498
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   code         1499 non-null   object
#  1   name         1499 non-null   object
#  2   countryname  1499 non-null   object
# dtypes: object(3)
# memory usage: 35.3+ KB

# %%
df_themes = df_norm.groupby(['code', 'name']).size().reset_index().rename(columns={0: 'count'}).sort_values(by='count', ascending=False)
df_themes
# Out:
#    code                                          name  count
# 5    11  Environment and natural resources management    223
# 3    10                             Rural development    202
# 19    8                             Human development    197
# 7     2                      Public sector governance    184
# 15    6         Social protection and risk management    158
# 11    4      Financial and private sector development    130
# 17    7                   Social dev/gender/inclusion    119
# 13    5                         Trade and integration     72
# 21    9                             Urban development     47
# 1     1                           Economic management     33
# 4    11                                                   27
# 10    4                                                   16
# 6     2                                                   15
# 2    10                                                   14
# ...

# %% [markdown]
# ### 3. In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.

# %%
import numpy as np

df_themes = df_themes.replace('', np.nan).dropna()
df_themes
# Out:
#    code                                          name  count
# 5    11  Environment and natural resources management    223
# 3    10                             Rural development    202
# 19    8                             Human development    197
# 7     2                      Public sector governance    184
# 15    6         Social protection and risk management    158
# 11    4      Financial and private sector development    130
# 17    7                   Social dev/gender/inclusion    119
# 13    5                         Trade and integration     72
# 21    9                             Urban development     47
# 1     1                           Economic management     33
# 9     3                                   Rule of law     12

# %%
df_norm_clean = pd.merge(df_norm, df_themes, how='left', on='code')
df_norm_clean.head()
# Out:
#   code                                 name_x  \
# 0    8                      Human development
# 1   11
# 2    1                    Economic management
# 3    6  Social protection and risk management
# 4    5                  Trade and integration
#
#                                countryname  \
# 0  Federal Democratic Republic of Ethiopia
# 1  Federal Democratic Republic of Ethiopia
# 2                      Republic of Tunisia
# 3                      Republic of Tunisia
# 4                                   Tuvalu
#
#                                          name_y  count
# 0                             Human development    197
# 1  Environment and natural resources management    223
# 2                           Economic management     33
# 3         Social protection and risk management    158
# 4                         Trade and integration     72

# %%
df_norm_clean.drop(columns='name_x', axis=1, inplace=True)
df_norm_clean.rename(columns={"name_y": "name"}, inplace=True)
df_norm_clean.head()
# Out:
#   code                              countryname  \
# 0    8  Federal Democratic Republic of Ethiopia
# 1   11  Federal Democratic Republic of Ethiopia
# 2    1                      Republic of Tunisia
# 3    6                      Republic of Tunisia
# 4    5                                   Tuvalu
#
#                                            name  count
# 0                             Human development    197
# 1  Environment and natural resources management    223
# 2                           Economic management     33
# 3         Social protection and risk management    158
# 4                         Trade and integration     72

# %%
df_norm_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1499 entries, 0 to 1498
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   code         1499 non-null   object
#  1   countryname  1499 non-null   object
#  2   name         1499 non-null   object
#  3   count        1499 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 58.6+ KB
